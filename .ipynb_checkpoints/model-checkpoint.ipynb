fit_transform(df['Sex'])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    1  22.0      1      0   7.2500
# 1         1       1    0  38.0      1      0  71.2833
# 2         1       3    0  26.0      0      0   7.9250
# 3         1       1    0  35.0      1      0  53.1000
# 4         0       3    1  35.0      0      0   8.0500

# %%
X = df.drop('Survived', axis=1)
y = df['Survived']

# %%
#sc = StandardScaler()
#X = sc.fit_transform(X)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
print(X)
# Out:
# [[ 0.82737724  0.73769513 -0.52119766  0.43279337 -0.47367361 -0.50244517]
#  [-1.56610693 -1.35557354  0.57872934  0.43279337 -0.47367361  0.78684529]
#  [ 0.82737724 -1.35557354 -0.24621591 -0.4745452  -0.47367361 -0.48885426]
#  ...
#  [ 0.82737724 -1.35557354 -0.72743397  0.43279337  2.00893337 -0.17626324]
#  [-1.56610693  0.73769513 -0.24621591 -0.4745452  -0.47367361 -0.04438104]
#  [ 0.82737724  0.73769513  0.16625671 -0.4745452  -0.47367361 -0.49237783]]

# %%
lr = LogisticRegression(penalty='l2',verbose=1)

# %%
lr.fit(X,y)
# Out:
# [LibLinear]
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
print(lr.score(X,y))
# Out:
# 0.792368125701459

# %%
lrc = LogisticRegressionCV()
lrc.fit(X,y)
lrc.score(X,y)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.792368125701459

# %%
sv = SVC()
sv.fit(X,y)
sv.score(X,y)
# Out:
# 0.8383838383838383

# %%
lsv = LinearSVC(penalty='l1')
lsv.fit(X,y)
lsv.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f5c1a17b0b0c> in <module>
#       1 lsv = LinearSVC(penalty='l1')
# ----> 2 lsv.fit(X,y)
#       3 lsv.score(X,y)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     235             self.class_weight, self.penalty, self.dual, self.verbose,
#     236             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 237             self.loss, sample_weight=sample_weight)
#     238
#     239         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     908         check_consistent_length(sample_weight, X)
#     909
# --> 910     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#     911     raw_coef_, n_iter_ = liblinear.train_wrap(
#     912         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#     764     raise ValueError('Unsupported set of arguments: %s, '
#     765                      'Parameters: penalty=%r, loss=%r, dual=%r'
# --> 766                      % (error_string, penalty, loss, dual))
#     767
#     768
#
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True

# %%
import numpy as np
data = np.array([3,1,22,1,0,7.25])
data = data.reshape(1, -1)
sv.predict(data)
# Out:
# array([0])

# %%
import pickle
